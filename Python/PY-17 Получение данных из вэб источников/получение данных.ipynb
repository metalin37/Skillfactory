# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %% [markdown]
# Проверим ответ сервера — содержимое переменной response:

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа Response, который содержит всю нужную нам информацию. По умолчанию в квадратных скобках на экран выводится код статуса ответа. В данном случае он равен 200 — то есть запрос был корректным и сервер отдал нам нужную информацию. Значение кода статуса 404 означало бы, что страница по указанному адресу не найдена, а значение 403 — что синтаксис GET-запроса неверный.
#
# Код ответа в виде числовой переменной можно получить с помощью метода status_code:

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %% [markdown]
# код в 1 строку

# %%
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %% [markdown]
# РАБОТАЕМ С ОТВЕТОМ
#
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ в XML и JSON.
#
# ?
# Как получить доступ ко всей информации, которую содержит ответ?
#
# Текст ответа хранится в атрибуте text. Выведем значение атрибута на экран и посмотрим на его содержимое:

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2022-12-08T11:30:00+03:00",
#     "PreviousDate": "2022-12-07T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/12\/07\/daily_json.js",
#     "Timestamp": "2022-12-08T12:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 42.1176,
#             "Previous": 42.3449
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 37.0219,
#             "Previous": 37.0061
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 76.9281,
#             "Previous": 76.8638
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 15.9045,
#             "Previous": 15.9029
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 25.3534,
#             "Previous": 25.407
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 33.839,
#             "Previous": 34.0534
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 12.0125,
#             "Previous": 11.9918
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 16.0595,
#             "Previous": 15.9331
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 80.9482,
#             "Previous": 81.0386
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 10,
#             "Name": "Датских крон",
#             "Value": 88.9823,
#             "Previous": 89.5571
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 62.9372,
#             "Previous": 62.9103
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 65.8966,
#             "Previous": 66.1087
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 77.1318,
#             "Previous": 76.9902
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 13.3248,
#             "Previous": 13.4088
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 46.1112,
#             "Previous": 46.49
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 74.0873,
#             "Previous": 74.0857
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 10,
#             "Name": "Китайских юаней",
#             "Value": 89.9043,
#             "Previous": 89.6835
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 32.2497,
#             "Previous": 32.1192
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 62.6347,
#             "Previous": 63.3334
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 14.0535,
#             "Previous": 14.0941
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 13.4381,
#             "Previous": 13.4412
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 83.4604,
#             "Previous": 83.6808
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 46.3319,
#             "Previous": 46.3906
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 61.6638,
#             "Previous": 61.6164
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 33.7807,
#             "Previous": 33.7686
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 17.9821,
#             "Previous": 17.9744
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 55.7712,
#             "Previous": 55.7958
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 17.0413,
#             "Previous": 17.0343
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 27.222,
#             "Previous": 27.3547
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 60.4015,
#             "Previous": 60.507
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 66.8265,
#             "Previous": 66.6705
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 36.2824,
#             "Previous": 36.2677
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 47.6184,
#             "Previous": 47.7027
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 45.8492,
#             "Previous": 46.0881
#         }
#     }
# }

# %% [markdown]
# Как правило, при работе над реальным проектом на этапе получения данных мы уже понимаем, с какими форматами данных нам придётся работать. На предлагаемом для работы ресурсе информация есть как в JSON-формате, так и в XML. По нашему запросу ресурс возвращает информацию в JSON-формате, однако в настоящий момент результат хранится как единая строка. Проверить тип данных полученного ответа можно, воспользовавшись функцией type().
#
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь. В объект ответа Response  из библиотеки requests уже встроен метод json() .
#
# Импортируем функцию pprint(), применим к полученному ответу метод json() и выведем полученный результат на экран:

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-12-08T11:30:00+03:00',
#  'PreviousDate': '2022-12-07T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/12/07/daily_json.js',
#  'Timestamp': '2022-12-08T12:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 15.9029,
#                     'Value': 15.9045},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 42.3449,
#                     'Value': 42.1176},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 37.0061,
#                     'Value': 37.0219},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 34.0534,
#                     'Value': 33.839},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 11.9918,
#                     'Value': 12.0125},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 25.407,
#                     'Value': 25.3534},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 46.49,
#                     'Value': 46.1112},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 66.6705,
#                     'Value': 66.8265},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайских юаней',
#                     'Nominal': 10,
#                     'NumCode': '156',
#                     'Previous': 89.6835,
#                     'Value': 89.9043},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 27.3547,
#                     'Value': 27.222},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датских крон',
#                     'Nominal': 10,
#                     'NumCode': '208',
#                     'Previous': 89.5571,
#                     'Value': 88.9823},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 66.1087,
#                     'Value': 65.8966},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 76.8638,
#                     'Value': 76.9281},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 81.0386,
#                     'Value': 80.9482},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 15.9331,
#                     'Value': 16.0595},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 76.9902,
#                     'Value': 77.1318},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 46.0881,
#                     'Value': 45.8492},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 74.0857,
#                     'Value': 74.0873},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 47.7027,
#                     'Value': 47.6184},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 13.4088,
#                     'Value': 13.3248},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 32.1192,
#                     'Value': 32.2497},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 63.3334,
#                     'Value': 62.6347},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 14.0941,
#                     'Value': 14.0535},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 13.4412,
#                     'Value': 13.4381},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 60.507,
#                     'Value': 60.4015},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 46.3906,
#                     'Value': 46.3319},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 61.6164,
#                     'Value': 61.6638},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 17.9744,
#                     'Value': 17.9821},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 33.7686,
#                     'Value': 33.7807},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 17.0343,
#                     'Value': 17.0413},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 62.9103,
#                     'Value': 62.9372},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 55.7958,
#                     'Value': 55.7712},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 83.6808,
#                     'Value': 83.4604},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 36.2677,
#                     'Value': 36.2824}}}

# %% [markdown]
# Теперь данные находятся в словаре и можно легко получать необходимые значения.
#
# Например, по ключу Valute мы можем обратиться к вложенному словарю, который содержит информацию о мировых валютах. Выведем на экран, например, информацию о евро (EUR):

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 66.1087,
#  'Value': 65.8966}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ
#
# Получим HTML-код интересующей нас страницы.
#
# Для этого отправим GET-запрос с помощью библиотеки requests и метода get() и посмотрим на текст ответа на наш запрос (как мы помним, он содержится в атрибуте text):

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#   <link href="/front-build/css/main.css" rel="stylesheet">
#   <link href="/front-build/css/app.css?v=5" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="manifest" href="/site.webmanifest">
#   <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#f26e40">
#   <meta name="msapplication-TileColor" content="#f26e40">
#   <meta name="theme-color" content="#ffffff">
#
#   <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021">
#
#   <meta name="yandex-verification" content="8c90b02c84ac3b72"/>
#   <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#   <script>window.yaContextCb = window.yaContextCb || []</script>
#   <script src="https://yandex.ru/ads/system/context.js" async></script>
#
#
#
#   <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#   <meta property="og:site_name" content="N + 1 — главное издание о науке, технике и технологиях"/>
#   <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta property="og:image" content="https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg"/>
#   <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021"/>
#   <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta property="og:type" content="article"/>
#
#     <meta itemprop="datePublished" content="2021-10-11"/>
#   <!-- amp page -->
#   <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#
#   <meta itemprop="datePublished" content="2021-10-11"/>
#
#
#
#       <meta name="mediator_author" content="Илья Ферапонтов"/>
#     <meta name="author" content="Илья Ферапонтов"/>
#
#   <meta name="copyright" content=""/>
#
#       <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2021/10/11/econobel2021"
#       },
#       "headline": "Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей",
#       "description": "",
#             "image": "https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg",
#
#           "author": {
#         "@type": "Person",
#         "name": "Илья Ферапонтов"
#         },
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://nplus1.ru/images-new/logo-alt.png"
#       }
#     },
#     "datePublished": "2021-10-11",
#       "dateModified": "2021-10-11"
#     }
#     </script>
#
#
#
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@nplusodin"/>
#   <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta name="twitter:image" content="https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg"/>
#
#   <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="antialiased">
# <div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">
#
#   <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"
#         data-ref-header
#         ref="headerRef">
#
#       <div id="progressBar" class="absolute bg-main-gray/5 bottom-0 left-0 top-0" style="z-index: -1"></div>
#
#   <div class="border-b border-main-gray h-full">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"
#          data-ref-header-container
#          ref="headerContainerRef">
#
#       <button aria-label="Go" data-ref-header-menu-btn
#               ref="headerMenuBtnRef"
#               id="topMenuBtn"
#               @click="menuOpen"
#               class="w-7.5 h-7.5">
#         <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_cross_menu"></use>
#           </svg>
#         </template>
#         <template v-else>
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_burger"></use>
#           </svg>
#         </template>
#       </button>
#
#       <div>
#                   <a href="/">
#                         <img src="/images-new/logo.svg" height="23" width="57" alt="as">
#                       </a>
#               </div>
#
#       <a href="/search" class="w-7.5 h-7.5">
#         <svg class="w-full h-full">
#           <use xlink:href="#n1_pupa"></use>
#         </svg>
#       </a>
#     </div>
#   </div>
#
#   <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavDesktop">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#
#
#         <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#
#         <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75"
#            href="https://offline.nplus1.ru/">N + offline</a>
#         <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75"
#            href="https://nplus.pro/">N + production</a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#         <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#
#                                     <a target="_blank" href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75">
#                 О нас
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75">
#                 Сложность
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75">
#                 Рекламодателям
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75">
#                 Авторам
#               </a>
#
#         </div>
#
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/869">Физика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/874">Зоология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/880">Астрономия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/768">Генетика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/890">Математика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/871">Космонавтика</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/876">Археология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/775">Нейронауки</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/767">На мышах</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/771">Звук</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/772">Красота</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/778">Научные закрытия</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/917">ИИ спешит на помощь</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/918">Когда рассеется дым</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/824">Книжная полка</a>
#                       </div>
#
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </nav>
#
#   <nav v-if="isOpenMobileMenu" id="mobNavMenu" class="relative bg-white max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavMobile">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/about">О
#           нас</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/difficult">Сложность</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/adv">Рекламодателям</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank"
#            href="https://nplus1.ru/news/2015/09/21/editor-thy-name">Вакансии</a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/869">Физика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/874">Зоология</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/880">Астрономия</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/768">Генетика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/890">Математика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/871">Космонавтика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/876">Археология</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/775">Нейронауки</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/767">На мышах</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/771">Звук</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/772">Красота</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/778">Научные закрытия</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/917">ИИ спешит на помощь</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/918">Когда рассеется дым</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/824">Книжная полка</a>
#
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#         <div class="flex gap-x-5 overflow-x-auto">
#
#           <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
#           <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
#         </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#
#     </div>
#   </nav>
#
# </header>
#
#
#   <app-heading-nav></app-heading-nav>
#
#   <section class="mb-15 md:mb-20">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9 relative overflow-hidden"
#          data-heading-wrap>
#
#       <!--tags-->
#
#               <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
#           <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                           <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">13:04</span>
#               </span>
#
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/news/2021/10/11">
#               <span class="group-hover:text-main transition-colors duration-75">11.10.21</span>
#             </a>
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/material/difficulty/1">
#               <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#                 <use xlink:href="#n1_star"></use>
#               </svg>
#               <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#             </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="/search/empty/898">
#                   <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#                 </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="/search/empty/785">
#                   <span class="group-hover:text-main transition-colors duration-75">Нобелевская премия</span>
#                 </a>
#
#           </div>
#           <div class="hidden lg:flex items-center gap-x-2">
#
#             <a href="https://nplus1.ru/material-print/30917" target="_blank" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22"
#                    height="30" viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"/>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"/>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"/>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"/>
#               </svg>
#             </a>
#
#
#
#
#
#
#             <app-copy-material
#                     link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                     type="full-2"
#             ></app-copy-material>
#
#           </div>
#
#           <div class="w-full flex flex-col mt-5">
#                       </div>
#
#         </div>
#
#       <!--dotes menu mobile-->
#       <template v-if="isMobile">
#         <button
#                 @click="openMobileDotsMenu"
#                 class="absolute flex right-5 top-5 z-30 text-main-black" >
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30" fill="none"
#                class="fill-current">
#             <path fill-rule="evenodd" clip-rule="evenodd"
#                   d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z"/>
#           </svg>
#         </button>
#         <div ref="mobileDotsMenuRef"
#              :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }">
#
#
#
#
#
#           <app-copy-material
#                   link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                   type="mobile"
#           ></app-copy-material>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"/>
#             </svg>
#           </button>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <rect x="0.833984" y="0.5" width="28.3333" height="39"/>
#               <line x1="5.66732" y1="10.1665" x2="24.334" y2="10.1665"/>
#               <line x1="5.66732" y1="28.8335" x2="24.334" y2="28.8335"/>
#               <line x1="5.66732" y1="19.5" x2="24.334" y2="19.5"/>
#             </svg>
#           </button>
#
#         </div>
#       </template>
#
#       <!-- main image -->
#             <!--main-->
#
#       <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
#         <div class="flex flex-col">
#
#
#           <h1 class="text-34 md:text-42 xl:text-52 break-words mb-6">
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#           </h1>
#
#
#
#                       <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#
#                 <span class="whitespace-nowrap">
#
#
#                   <a class="underline" href="/author/ilya-ferapontov">Илья Ферапонтов</a>
#                 </span>
#
#
#
#
#             </div>
#
#           <div data-lmb-0 class="mb-14">
#
#
#
#                                     <BaseGalleryMain :gid="18670"></BaseGalleryMain>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a> на официальном сайте Нобелевской премии.</p></div>
#
#
#
#
#
#                                     <BaseGalleryMain :gid="1381"></BaseGalleryMain>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале <a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на бедных»</a>. В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6"><i>Сергей Кузнецов</i></p></div>
#
#
#                       </div>
#
#
#
#
#
#
#
#           <div class="text-18">
#
#
#             <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
#
#           </div>
#
#         </div>
#       </div>
#
#       <!--right sidebar-->
#
#       <div class="hidden md:block md:col-span-4 lg:col-span-3 mt-10 ">
#
#
#
#
#
#                               <a href="http://nplus.pro/?utm_source=nplus1&utm_medium=banner&utm_campaign=bodykit">
#               <img src="/images-new/banner-test.png" class="w-full" alt="banner">
#             </a>
#
#             <!-- ba2 -->
#             <!--AdFox START-->
#             <!--nplus1_dir-->
#             <!--Площадка: https://nplus1.ru/ / * / *-->
#             <!--Тип баннера: CLICKIO html5-->
#             <!--Расположение: <верх страницы>-->
#             <div id="adfox_153934342663011746" class="bg-gray-100 mt-2 py-4 w-full"></div>
#
#
#
#
#
#
#         <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
#       </div>
#
#
#
#     </div>
#   </section>
#
#
#       <section class="mb-15 md:mb-20">
#
#
#   <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
#
#     <!--tags-->
#
#           <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
#         <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                                     <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">12:59</span>
#               </span>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/news/2022/06/06">
#             <span class="group-hover:text-main transition-colors duration-75">06.06.22</span>
#           </a>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/material/difficulty/1">
#             <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#               <use xlink:href="#n1_star"></use>
#             </svg>
#             <span class="group-hover:text-main transition-colors duration-75">1.6</span>
#           </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="/search/empty/812">
#                 <span class="group-hover:text-main transition-colors duration-75">Партнерский материал</span>
#               </a>
#                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="/search/empty/898">
#                 <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#               </a>
#
#
#         </div>
#         <div class="hidden lg:flex items-center gap-x-2">
#
#
#
#
#
#
#
#
#                       <a href="https://nplus1.ru/material-print/32984" aria-label="Go" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22" height="30"
#                    viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"></rect>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"></line>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"></line>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"></line>
#               </svg>
#             </a>
#
#
#
#
#
#
#                       <app-copy-material
#                     link="https://nplus1.ru/news/2022/06/06/are-you-rational"
#                     type="full-2"
#             ></app-copy-material>
#
#         </div>
#       </div>
#
#     <!--main image  -->
#
#
#
#     <!--main-->
#
#     <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0 ">
#       <div class="flex flex-col">
#
#         <div class="text-34 md:text-42 xl:text-52 break-words">
#           Неразумная экономика
#         </div>
#
#                   <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Насколько типичны ваши решения о покупках?</p>
#
#
#         <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#             <a class="underline whitespace-nowrap"
#                href="/author/albina-kudryakova">Альбина Кудрякова</a>
#
#
#                   </div>
#
#         <div class="n1_material text-18">
#           <p class="mb-6">Так ли мы рациональны? Поведенческая экономика утверждает, что вообще-то не очень. Благодаря ей мы можем предположить, что вы выберете на ужин, какой напиток возьмете в баре и чем будете оплачивать покупки. Вместе с Тинькофф мы подготовили тест, который покажет, насколько ваше покупательское поведение отличается от поведения большинства, и расскажет, как на нас влияют цена, выбор, интерфейсы, люди и даже банковские карты. Ну а те, кто пройдет тест до конца, узнают, как получить карту Tinkoff Black, за обслуживание которой никогда не нужно будет платить.</p>
#         </div>
#
#         <div class="mt-5 md:mt-6">
#           <a class="inline-flex justify-center bg-main w-full py-4"
#              href="https://nplus1.ru/news/2022/06/06/are-you-rational">
#             <span class="text-white text-22 md:text-24">Читать дальше</span>
#           </a>
#         </div>
#
#       </div>
#     </div>
#
#   </div>
# </section>
#
#
#
#
#
#
#
#
#       <section class="mb-15 md:mb-20">
#       <div id="adfox_154408219501673625" class="bg-gray-100 w-full"></div>
#     </section>
#
#
#   <div class="mb-1 w-full overflow-hidden">
#     <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
#   <template v-slot:default="slotProps">
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/716625/6375fb321a249_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/716626/6375fb325998a_hl_cover_h.jpg">
#             <img src="https://app-images.website.yandexcloud.net/716626/6375fb325998a_hl_cover_h.jpg"
#                  style="background-color: "
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Китаец попытался вылечить грибок в паху внутривенной инъекцией ртути">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/11/17">
#         <span class="group-hover:text-main transition-colors duration-75">17.11.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/873">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Медицина
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           2.1
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/11/17/quicksilver-rush">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           Китаец попытался вылечить грибок в паху внутривенной инъекцией ртути</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Симптомы острого отравления металлом удалось купировать, но к выписке из больницы полностью он не вывелся</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/716990/63771d6bdfd38_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/716991/63771d6c2aaf8_hl_cover_h.jpg">
#             <img src="https://app-images.website.yandexcloud.net/716991/63771d6c2aaf8_hl_cover_h.jpg"
#                  style="background-color: "
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Генетики прочитали ДНК сына и внука средневекового венгерского короля Матьяша Корвина">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/11/18">
#         <span class="group-hover:text-main transition-colors duration-75">18.11.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/877">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Антропология
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           3.1
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/11/18/hunyadi">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           Генетики прочитали ДНК сына и внука средневекового венгерского короля Матьяша Корвина</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Они умерли в начале XVI века</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/707554/3cf1789b1d31e16429009558c4c411cc.png">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/707553/d0443796c01ac1945ea83d2bdef49341.png">
#             <img src="https://app-images.website.yandexcloud.net/707553/d0443796c01ac1945ea83d2bdef49341.png"
#                  style="background-color: #e2b22c"
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Позовите врача!">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/2022/10/14">
#         <span class="group-hover:text-main transition-colors duration-75">14.10.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/873">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Медицина
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           3.2
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/material/2022/10/14/better-call-a-doctor">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           Позовите врача!</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Что может и чего не может искусственный интеллект в медицине</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/720445/6381843166317_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/720446/63818431f2c1e_hl_cover_h.jpg">
#             <img src="https://app-images.website.yandexcloud.net/720446/63818431f2c1e_hl_cover_h.jpg"
#                  style="background-color: "
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Археологи уточнили возраст вытаявшей в Норвегии пары лыж">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/11/26">
#         <span class="group-hover:text-main transition-colors duration-75">26.11.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/876">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           1.5
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/11/26/ski">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           Археологи уточнили возраст вытаявшей в Норвегии пары лыж</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Ее изготовили между 668 и 775 годами нашей эры</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/722487/638742684693c_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/722493/d6fdad42460fffda49f62da288474f9a.jpg">
# ...
#       <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
#         <ul class="flex gap-3 text-gray-2">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#
# </footer>
#
#
#
# </div>
#
#
# <svg id="n1_star" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      width="16" height="16"
#      viewBox="3 3 16 16" fill="none">
#   <path d="M11 5V17"/>
#   <path d="M6.75781 6.75781L15.2431 15.2431"/>
#   <path d="M17 11L5 11"/>
#   <path d="M15.2422 6.75781L6.75691 15.2431"/>
# </svg>
# <svg id="n1_person" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 50 50" fill="none">
#   <circle cx="25" cy="25" r="24.5"/>
#   <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z"
#         stroke-miterlimit="10"/>
# </svg>
# <svg id="n1_tg" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <path d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"
#         class="fill-current"/>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
# </svg>
# <svg id="n1_vk" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_ok" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_tw" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_infinity" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink" width="64px" height="64px" viewBox="0 0 100 100"
#      preserveAspectRatio="xMidYMid">
#   <path fill="none" stroke="#ffffff" stroke-width="5" stroke-dasharray="146.25568908691406 110.33323913574219"
#         d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z"
#         stroke-linecap="round" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1.3157894736842106s" keyTimes="0;1"
#              values="0;256.58892822265625"></animate>
#   </path>
# </svg>
# <svg id="n1_cross" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 14 14"
#      fill="none">
#   <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"/>
#   <path d="M13 1L1 13" stroke="#F9F9F9"/>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#   <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#         fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 61 61">
#   <path class="fill-current" fill-rule="evenodd" clip-rule="evenodd"
#         d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z"/>
#   <path class="fill-current"
#         d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"/>
# </svg>
# <svg id="n1_circle_arrow" style="display:block;width:0;height:0" class="stroke-current"
#      xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30" fill="none">
#   <rect x="29.5" y="29.5" width="29" height="29" rx="14.5" transform="rotate(-180 29.5 29.5)"/>
#   <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"/>
# </svg>
# <svg id="n1_circle_arrow_solid" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 30 30" fill="none">
#   <mask id="path-1-inside-1_2694_77554">
#     <path fill-rule="evenodd" clip-rule="evenodd"
#           d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"/>
#   </mask>
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"
#         fill="#fff"/>
#   <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z"
#         fill="#fff" mask="url(#path-1-inside-1_2694_77554)"/>
# </svg>
# <svg id="n1_play" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
#   <path d="M18 35V15L36 25L18 35Z" class="stroke-current"/>
# </svg>
# <svg id="n1_pupa" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 23"
#      fill="none">
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z"
#         fill="#32363A"/>
# </svg>
# <svg id="n1_burger" style="display:block;width:0;height:0;" viewBox="0 0 30 30" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <line y1="6.5" x2="30" y2="6.5" stroke="#32363A"/>
#   <line y1="23.5" x2="30" y2="23.5" stroke="#32363A"/>
#   <line y1="15" x2="30" y2="15" stroke="#32363A"/>
# </svg>
# <svg id="n1_cross_menu" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30"
#      fill="none">
#   <path d="M4 4L26 26" stroke="#32363A"/>
#   <path d="M26 4L4 26" stroke="#32363A"/>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" xmlns="http://www.w3.org/2000/svg"
#      version="1.1" viewBox="0 0 752 752">
#   <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"/>
# </svg>
#
# <script src="/front-build/js/app.js?v=07122022"></script>
# <script src="/js/twitter/widgets.js"></script>
#
#   <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript" >
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
#   <div>
#     <img src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;" alt="" />
#     <img src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
#
#
#
#
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
#
#
#
#
#
# </body>
# </html>

# %% [markdown]
# Ответ содержит HTML-код страницы, к которой мы обратились.
#
# В отличие от предыдущего примера, где ответ возвращался в JSON-формате, мы не можем так просто преобразовать HTML-код в словарь и извлечь необходимую нам информацию.
#
# Для решения таких задач в Python существует специальная библиотека BeautifulSoup, о работе с которой мы поговорим в следующем юните.

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %% [markdown]
# Теперь мы можем извлекать данные из любой веб-страницы.
#
# Ранее мы уже получили содержимое страницы с помощью GET-запроса и сохранили информацию в переменной response , теперь создадим объект BeautifulSoup с именем page, указывая в качестве параметра html.parser.
#
# Для примера получим информацию o title (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Если при запросе к сайту, а затем при его разборе с помощью BeautifulSoup в тексте страницы не находится нужный тег, попробуйте вывести на печать пару тысяч символов текста страницы. Если там обнаружится нечто похожее на капчу, возможно, сайт посчитал вас роботом и отказывается выдавать содержимое. Чтобы получить его, попробуйте «притвориться» браузером при запросе из скрипта:
#
# requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
# User-Agent своего браузера можно узнать по этой ссылке https://n5m.ru/usagent.html

# %% [markdown]
# ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ
#
# Выполним поставленную ранее задачу: получить информацию о странице и извлечь заголовок статьи, опубликованной на этой странице, дату публикации, а также текст статьи.
#
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён в тег <'h1'> … </'h1'> (заголовок первого уровня).
#
# Тогда мы можем получить его текст с помощью метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Но как же узнать, в каких именно тегах заключена необходимая информация?
#
# Проще всего это сделать с помощью так называемого инструмента разработчика, который есть во всех современных браузерах. Покажем, как открыть данный инструмент на примере использования браузера Google Chrome.
#
# Устанавливаем курсор на элементе страницы (заголовок статьи), информацию о котором хотим получить, нажимаем на правую клавишу мыши и в выпадающем списке выбираем пункт «Просмотреть код элемента» или «Посмотреть код» в зависимости от браузера.
# В открывшемся окне инструмента разработчика видим, что информация о заголовке статьи заключена в теге <'h1'> … </'h1'>.
# Аналогично получим информации о теге, который содержит дату написания статьи, отображаемую в левом верхнем углу страницы.
# Итак, нам нужен тег <'span> … </'span>.

# %% [markdown]
# Теперь получим данные из него с помощью уже известного метода find(), передав название нужного тега:

# %%
print(page.find('span').text) # Выводим на экран содержимое атрибута text тега span
# Out:
# 13:04

# %% [markdown]
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
def wiki_header(url):
    response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
    page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
    return(page.find('span').text)

wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %% [markdown]
# НЕУНИКАЛЬНЫЕ ТЕГИ: ИЗВЛЕКАЕМ ТЕКСТ СТАТЬИ
#
# Теперь получим сам текст статьи. Как вы уже знаете, первым делом необходимо определить, в какой тег он заключён. Применим, как и ранее, инструмент разработчика.
# Видим, что искомый текст заключён в тег  <'div> … </'div> . Попробуем извлечь его уже известным нам способом — с помощью метода find() — и выведем его на экран.

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %% [markdown]
# Мы увидели не то, что ожидали — кучу текста, не имеющего отношения к тому, что мы искали...
#
# ?
# В чём же проблема?
#
# Дело в том, что теги <'div> … </'div> очень распространённые и на странице их очень много. Метод find() нашёл первый из них, но это не то, что нам надо.
#
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, что у искомого текста есть свой класс — n1_material text-18 :

# %% [markdown]
# Передадим название класса в метод find() с помощью аргумента class_ и получим текст статьи:

# %%
print(page.find('div', class_='n1_material text-18').text) # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %% [markdown]
# CБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ
#
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег <a> … </a>. Попробуем использовать find():

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %% [markdown]
# Мы получили только одну ссылку, хотя на странице их явно больше.
#
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 943

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Opa', 'Opal', 'Open Programming Language', 'OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OpenQASM', 'OPS5', 'OptimJ', 'Orc']

# %% [markdown]
# токен вк f3b98274f3b98274f3b982748df0a84e39ff3b9f3b9827490283db2245b35612b793e50

# %% [markdown]
# ЗАПРОС К API ИЗ КОДА
#
# Продолжаем пользоваться всё той же библиотекой requests.

# %%
import requests # Импортируем модуль requests
token = 'f3b98274f3b98274f3b982748df0a84e39ff3b9f3b9827490283db2245b35612b793e50' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода json(), после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
print(user['first_name']) # Выводим дату рождения первого пользователя на экран
# Out:
# Павел

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
#
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 4,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Илья',
#                'id': 5,
#                'is_closed': False,
#                'last_name': 'Перекопский'},
#               {'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 6,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 7,
#                'is_closed': True,
#                'last_name': 'Кобылянский'},
#               {'can_access_closed': True,
#                'first_name': 'Аки',
#                'id': 8,
#                'is_closed': False,
#                'last_name': 'Сепиашвили'},
#               {'can_access_closed': False,
#                'first_name': 'Настя',
#                'id': 9,
#                'is_closed': True,
#                'last_name': 'Васильева'},
#               {'can_access_closed': False,
#                'first_name': 'Александр',
#                'id': 10,
#                'is_closed': True,
#                'last_name': 'Кузнецов'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 11,
#                'is_closed': False,
#                'last_name': 'Петров'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 12,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 13,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 14,
#                'is_closed': False,
#                'last_name': 'Городецкий'},
#               {'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 15,
#                'is_closed': True,
#                'last_name': 'Васильков'},
#               {'can_access_closed': False,
#                'first_name': 'Виктория',
#                'id': 16,
#                'is_closed': True,
#                'last_name': 'Беспалова'},
#               {'can_access_closed': True,
#                'first_name': 'Александр',
#                'id': 17,
#                'is_closed': False,
#                'last_name': 'Беспалов'},
#               {'can_access_closed': True,
#                'first_name': 'Симон',
#                'id': 18,
#                'is_closed': False,
#                'last_name': 'Кречмер'},
#               {'can_access_closed': True,
#                'first_name': 'Светочек',
#                'id': 19,
#                'is_closed': False,
#                'last_name': 'Аленький'},
#               {'can_access_closed': False,
#                'first_name': 'Илья',
#                'id': 20,
#                'is_closed': True,
#                'last_name': 'Турпиашвили'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 21,
#                'is_closed': False,
#                'last_name': 'Равдоникас'},
#               {'can_access_closed': True,
#                'first_name': 'Семен',
#                'id': 22,
#                'is_closed': False,
#                'last_name': 'Воронин'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 23,
#                'is_closed': False,
#                'last_name': 'Столбовский'},
#               {'can_access_closed': False,
#                'first_name': 'Рамми',
#                'id': 24,
#                'is_closed': True,
#                'last_name': 'Цицуашвили'},
#               {'can_access_closed': False,
#                'first_name': 'Анастасия',
#                'id': 25,
#                'is_closed': True,
#                'last_name': 'Ведущенко'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 26,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 27,
#                'is_closed': False,
#                'last_name': 'Семиколенова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 28,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 29,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 30,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 31,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 32,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 33,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Татьяна',
#                'id': 34,
#                'is_closed': True,
#                'last_name': 'Плуталова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 35,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 36,
#                'is_closed': False,
#                'last_name': 'Смирнов'},
#               {'can_access_closed': False,
#                'first_name': 'Михаил',
#                'id': 37,
#                'is_closed': True,
#                'last_name': 'Казекин'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 38,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'David',
#                'id': 39,
#                'is_closed': False,
#                'last_name': 'Mirelli'},
#               {'can_access_closed': True,
#                'first_name': 'Олег',
#                'id': 40,
#                'is_closed': False,
#                'last_name': 'Чередников'},
#               {'can_access_closed': True,
#                'first_name': 'Владислав',
#                'id': 41,
#                'is_closed': False,
#                'last_name': 'Миллер'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 42,
#                'is_closed': False,
#                'last_name': 'Маркин'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 43,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Тамара',
#                'id': 44,
#                'is_closed': False,
#                'last_name': 'Мирилашвили'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 45,
#                'is_closed': False,
#                'last_name': 'Виноградов'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 46,
#                'is_closed': False,
#                'last_name': 'Лесохин'},
#               {'deactivated': 'banned',
#                'first_name': 'Габриел',
#                'id': 47,
#                'last_name': 'Шалел'},
#               {'can_access_closed': True,
#                'first_name': 'Миша',
#                'id': 48,
#                'is_closed': False,
#                'last_name': 'Мельников'},
#               {'can_access_closed': True,
#                'first_name': 'Бот',
#                'id': 49,
#                'is_closed': False,
#                'last_name': 'Мороз'},
#               {'can_access_closed': True,
#                'first_name': 'Снегурочка',
#                'id': 50,
#                'is_closed': False,
#                'last_name': 'Морозова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 51,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 52,
#                'is_closed': False,
#                'last_name': 'Вознесенский'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 53,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 54,
#                'is_closed': False,
#                'last_name': 'Фуртикова'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 55,
#                'is_closed': False,
#                'last_name': 'Смирнов'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 56,
#                'is_closed': False,
#                'last_name': 'Чернышев'},
#               {'deactivated': 'deleted',
#                'first_name': 'Сергей',
#                'id': 57,
#                'last_name': 'Владимиров'},
#               {'deactivated': 'banned',
#                'first_name': 'Александр',
#                'id': 58,
#                'last_name': 'Ковалев'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 59,
#                'is_closed': False,
#                'last_name': 'Желудкова'},
#               {'can_access_closed': False,
#                'first_name': 'Даниэль',
#                'id': 60,
#                'is_closed': True,
#                'last_name': 'Розенберг'},
#               {'can_access_closed': True,
#                'first_name': 'Григорий',
#                'id': 61,
#                'is_closed': False,
#                'last_name': 'Конрадт'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 62,
#                'is_closed': False,
#                'last_name': 'Ланина'},
#               {'can_access_closed': False,
#                'first_name': 'Никита',
#                'id': 63,
#                'is_closed': True,
#                'last_name': 'Поликарпов'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 64,
#                'last_name': ''},
#               {'deactivated': 'banned',
#                'first_name': 'Mikhail',
#                'id': 65,
#                'last_name': 'Torline'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 66,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 67,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Вика',
#                'id': 68,
#                'is_closed': False,
#                'last_name': 'Мирилашвили'},
#               {'can_access_closed': False,
#                'first_name': 'Avi',
#                'id': 69,
#                'is_closed': True,
#                'last_name': 'Shalel'},
#               {'can_access_closed': True,
#                'first_name': 'Митя',
#                'id': 70,
#                'is_closed': False,
#                'last_name': 'Миронов'},
#               {'can_access_closed': False,
#                'first_name': 'Людмила',
#                'id': 71,
#                'is_closed': True,
#                'last_name': 'Романченко'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 72,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Надежда',
#                'id': 73,
#                'is_closed': True,
#                'last_name': 'Лебедева'},
#               {'can_access_closed': True,
#                'first_name': 'Наташа',
#                'id': 74,
#                'is_closed': False,
#                'last_name': 'Филимонова'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 75,
#                'is_closed': False,
#                'last_name': 'Копылова'},
#               {'deactivated': 'banned',
#                'first_name': 'David',
#                'id': 76,
#                'last_name': 'Biniaurischwili'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 77,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Anna',
#                'id': 78,
#                'is_closed': True,
#                'last_name': 'Rudneva'},
#               {'deactivated': 'banned',
#                'first_name': 'Давид',
#                'id': 79,
#                'last_name': 'Спектер'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 80,
#                'last_name': ''},
#               {'deactivated': 'banned',
#                'first_name': 'Влад',
#                'id': 81,
#                'last_name': 'Куценко'},
#               {'deactivated': 'banned',
#                'first_name': 'Tami',
#                'id': 82,
#                'last_name': 'Shalel'},
#               {'deactivated': 'banned',
#                'first_name': 'Дмитрий',
#                'id': 83,
#                'last_name': 'Тихомиров'},
#               {'can_access_closed': True,
#                'first_name': 'Фёдор',
#                'id': 84,
#                'is_closed': False,
#                'last_name': 'Медведев'},
#               {'can_access_closed': False,
#                'first_name': 'Mikhail',
#                'id': 85,
#                'is_closed': True,
#                'last_name': 'Gennadevich'},
#               {'can_access_closed': False,
#                'first_name': 'Никита',
#                'id': 86,
#                'is_closed': True,
#                'last_name': 'Пиастро'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 87,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Полина',
#                'id': 88,
#                'is_closed': False,
#                'last_name': 'Олейник'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 89,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Малина',
#                'id': 90,
#                'is_closed': False,
#                'last_name': 'Baci'},
#               {'can_access_closed': True,
#                'first_name': 'Дарья',
#                'id': 91,
#                'is_closed': False,
#                'last_name': 'Белинская'},
#               {'can_access_closed': False,
#                'first_name': 'Екатерина',
#                'id': 92,
#                'is_closed': True,
#                'last_name': 'Тихонова'},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 93,
#                'is_closed': False,
#                'last_name': 'Забоева'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 94,
#                'is_closed': False,
#                'last_name': 'Теплова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 95,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 96,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 97,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 98,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Наталья',
#                'id': 99,
#                'is_closed': True,
#                'last_name': 'Брагина'},
#               {'can_access_closed': True,
#                'first_name': 'Администрация ВКонтакте',
#                'id': 100,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Администратор',
#                'id': 101,
#                'is_closed': False,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 102,
#                'is_closed': False,
#                'last_name': 'Тенева'},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 103,
#                'is_closed': False,
#                'last_name': 'Романцева'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 104,
#                'is_closed': False,
#                'last_name': 'Ребикова'},
#               {'deactivated': 'banned',
#                'first_name': 'Roman',
#                'id': 105,
#                'last_name': 'Ponomarenko'},
#               {'can_access_closed': True,
#                'first_name': 'Спотти',
#                'id': 106,
#                'is_closed': False,
#                'last_name': 'Космический'},
#               {'can_access_closed': False,
#                'first_name': 'Администрация',
#                'id': 107,
#                'is_closed': True,
#                'last_name': 'Б.'},
#               {'can_access_closed': False,
#                'first_name': 'Диана',
#                'id': 108,
#                'is_closed': True,
#                'last_name': 'Курбатова'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 109,
#                'is_closed': False,
#                'last_name': 'Горюнова'},
#               {'can_access_closed': False,
#                'first_name': 'Администрация',
#                'id': 110,
#                'is_closed': True,
#                'last_name': 'В.'},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 111,
#                'is_closed': False,
#                'last_name': 'Лаврова'},
#               {'can_access_closed': False,
#                'first_name': 'Евгения',
#                'id': 112,
#                'is_closed': True,
#                'last_name': 'Алексеева'},
#               {'can_access_closed': True,
#                'first_name': 'Владислав',
#                'id': 113,
#                'is_closed': False,
#                'last_name': 'Умнов'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 114,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 115,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 116,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Антон',
#                'id': 117,
#                'is_closed': False,
#                'last_name': 'Краснов'},
#               {'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 118,
#                'is_closed': True,
#                'last_name': 'Никулина'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 119,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 120,
#                'is_closed': False,
#                'last_name': 'Соколова'},
#               {'can_access_closed': True,
#                'first_name': 'Надежда',
#                'id': 121,
#                'is_closed': False,
#                'last_name': 'Сторчевая'},
#               {'can_access_closed': False,
#                'first_name': 'Надежда',
#                'id': 122,
#                'is_closed': True,
#                'last_name': 'Игошина'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 123,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 124,
#                'is_closed': False,
#                'last_name': 'Горбунова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 125,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 126,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 127,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 128,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 129,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 130,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Шурикен',
#                'id': 131,
#                'is_closed': True,
#                'last_name': 'Картошкин'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 132,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 133,
#                'is_closed': False,
#                'last_name': 'Харчев'},
#               {'can_access_closed': True,
#                'first_name': 'Илико',
#                'id': 134,
#                'is_closed': False,
#                'last_name': 'Шаптай'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 135,
#                'is_closed': False,
#                'last_name': 'Филатова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 136,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 137,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 138,
#                'is_closed': False,
#                'last_name': 'Рощин'},
#               {'deactivated': 'banned',
#                'first_name': 'Роман',
#                'id': 139,
#                'last_name': 'Чистяков'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 140,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 141,
#                'is_closed': True,
#                'last_name': 'Михайлов'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 142,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Машечка',
#                'id': 143,
#                'is_closed': False,
#                'last_name': 'Зайцева'},
#               {'can_access_closed': True,
#                'first_name': 'Oleg',
#                'id': 144,
#                'is_closed': False,
#                'last_name': 'Zinkevich'},
#               {'can_access_closed': True,
#                'first_name': 'Константин',
#                'id': 145,
#                'is_closed': False,
#                'last_name': 'Теплов'},
#               {'can_access_closed': True,
#                'first_name': 'Александра',
#                'id': 146,
#                'is_closed': False,
#                'last_name': 'Муромцева'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 147,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Артём',
#                'id': 148,
#                'is_closed': False,
#                'last_name': 'Абанин'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 149,
#                'is_closed': False,
#                'last_name': 'Лобакин'},
#               {'can_access_closed': True,
#                'first_name': 'Луиза',
#                'id': 150,
#                'is_closed': False,
#                'last_name': 'Левиева'},
#               {'deactivated': 'banned',
#                'first_name': 'Леонид',
#                'id': 151,
#                'last_name': 'Добронов'},
#               {'can_access_closed': False,
#                'first_name': 'Илара',
#                'id': 152,
#                'is_closed': True,
#                'last_name': 'Юнаева'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 153,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Елисей',
#                'id': 154,
#                'is_closed': True,
#                'last_name': 'Замахов'},
#               {'deactivated': 'banned',
#                'first_name': 'Dennis',
#                'id': 155,
#                'last_name': 'Yurlov'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 156,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 157,
#                'last_name': ''},
#               {'deactivated': 'banned',
#                'first_name': 'Владислав',
#                'id': 158,
#                'last_name': 'Гатилов'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 159,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Васильев',
#                'id': 160,
#                'is_closed': True,
#                'last_name': 'Сергеевич'},
#               {'can_access_closed': True,
#                'first_name': 'Валентина',
#                'id': 161,
#                'is_closed': False,
#                'last_name': 'Савосина'},
#               {'can_access_closed': True,
#                'first_name': 'Александра',
#                'id': 162,
#                'is_closed': False,
#                'last_name': 'Аленичева'},
#               {'can_access_closed': False,
#                'first_name': 'Анастасия',
#                'id': 163,
#                'is_closed': True,
#                'last_name': 'Романько'},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 164,
#                'is_closed': True,
#                'last_name': 'Ткаченко'},
#               {'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 165,
#                'is_closed': False,
#                'last_name': 'Романько'},
#               {'can_access_closed': True,
#                'first_name': 'Дмитрий',
#                'id': 166,
#                'is_closed': False,
#                'last_name': 'Коменденко'},
#               {'can_access_closed': True,
#                'first_name': 'Демид',
#                'id': 167,
#                'is_closed': False,
#                'last_name': 'Кириленко'},
#               {'can_access_closed': True,
#                'first_name': 'Вероника',
#                'id': 168,
#                'is_closed': False,
#                'last_name': 'Кириленко'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 169,
#                'is_closed': False,
#                'last_name': 'Чистоклетова'},
#               {'can_access_closed': True,
#                'first_name': 'Богдан',
#                'id': 170,
#                'is_closed': False,
#                'last_name': 'Жидков'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 171,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Aleksei',
#                'id': 172,
#                'is_closed': True,
#                'last_name': 'Gorodetskii'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 173,
#                'is_closed': False,
#                'last_name': 'Чепурная'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 174,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 175,
#                'is_closed': False,
#                'last_name': 'Захаренков'},
#               {'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 176,
#                'is_closed': False,
#                'last_name': 'Смирнов'},
#               {'can_access_closed': False,
#                'first_name': 'Екатерина',
#                'id': 177,
#                'is_closed': True,
#                'last_name': 'Абраменко'},
#               {'can_access_closed': False,
#                'first_name': 'Марья',
#                'id': 178,
#                'is_closed': True,
#                'last_name': 'Безносова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 179,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 180,
#                'is_closed': False,
#                'last_name': 'Корнев'},
#               {'deactivated': 'banned',
#                'first_name': 'Андрей',
#                'id': 181,
#                'last_name': 'Матвеев'},
#               {'can_access_closed': True,
#                'first_name': 'Николай',
#                'id': 182,
#                'is_closed': False,
#                'last_name': 'Андреев'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 183,
#                'is_closed': False,
#                'last_name': 'Кретова'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 184,
#                'is_closed': False,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': False,
#                'first_name': 'Вадим',
#                'id': 185,
#                'is_closed': True,
#                'last_name': 'Рудковский'},
#               {'can_access_closed': True,
#                'first_name': 'Ольга',
#                'id': 186,
#                'is_closed': False,
#                'last_name': 'Савинкина-Титова'},
#               {'deactivated': 'banned',
#                'first_name': 'Сергей',
#                'id': 187,
#                'last_name': 'Воскресенкий'},
#               {'can_access_closed': False,
#                'first_name': 'Евгений',
#                'id': 188,
#                'is_closed': True,
#                'last_name': 'Лыков'},
#               {'can_access_closed': True,
#                'first_name': 'Вероника',
#                'id': 189,
#                'is_closed': False,
#                'last_name': 'Лежнева'},
#               {'can_access_closed': True,
#                'first_name': 'Вадим',
#                'id': 190,
#                'is_closed': False,
#                'last_name': 'Колосов'},
#               {'deactivated': 'banned',
#                'first_name': 'Гена',
#                'id': 191,
#                'last_name': 'Загальский'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 192,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Иван',
#                'id': 193,
#                'is_closed': False,
#                'last_name': 'Кораблев-Дайсон'},
#               {'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 194,
#                'is_closed': True,
#                'last_name': 'Гребнев'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 195,
#                'is_closed': False,
#                'last_name': 'Келим'},
#               {'can_access_closed': False,
#                'first_name': 'Екатерина',
#                'id': 196,
#                'is_closed': True,
#                'last_name': 'Караваева'},
#               {'can_access_closed': False,
#                'first_name': 'Дарья',
#                'id': 197,
#                'is_closed': True,
#                'last_name': 'Бондаренко'},
#               {'can_access_closed': False,
#                'first_name': 'Вальтер',
#                'id': 198,
#                'is_closed': True,
#                'last_name': 'Киршнер'},
#               {'can_access_closed': False,
#                'first_name': 'Елена',
#                'id': 199,
#                'is_closed': True,
#                'last_name': 'Жигалова'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 200,
#                'is_closed': False,
#                'last_name': 'Стрельников'},
#               {'can_access_closed': True,
#                'first_name': 'Игнатий',
#                'id': 201,
#                'is_closed': False,
#                'last_name': 'Дьяков'},
#               {'deactivated': 'banned',
#                'first_name': 'Максим',
#                'id': 202,
#                'last_name': 'Ластовка'},
#               {'can_access_closed': True,
#                'first_name': 'Зоя',
#                'id': 203,
#                'is_closed': False,
#                'last_name': 'Барабанова'},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 204,
#                'is_closed': False,
#                'last_name': 'Скрябина'},
#               {'can_access_closed': False,
#                'first_name': 'Ирина',
#                'id': 205,
#                'is_closed': True,
#                'last_name': 'Ямщикова'},
#               {'can_access_closed': True,
#                'first_name': 'Юрий',
#                'id': 206,
#                'is_closed': False,
#                'last_name': 'Скрелин'},
#               {'can_access_closed': True,
#                'first_name': 'Yulia',
#                'id': 207,
#                'is_closed': False,
#                'last_name': 'Bekmukhamedova'},
#               {'can_access_closed': False,
#                'first_name': 'Гена',
#                'id': 208,
#                'is_closed': True,
#                'last_name': 'Зарохин'},
#               {'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 209,
#                'is_closed': False,
#                'last_name': 'Дьячкова'},
#               {'can_access_closed': True,
#                'first_name': 'Аня',
#                'id': 210,
#                'is_closed': False,
#                'last_name': 'Дормидонтова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 211,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Алёна',
#                'id': 212,
#                'is_closed': False,
#                'last_name': 'Фёдорова'},
#               {'can_access_closed': False,
#                'first_name': 'Максим',
#                'id': 213,
#                'is_closed': True,
#                'last_name': 'Казанский'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 214,
#                'is_closed': False,
#                'last_name': 'Зелёный'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 215,
#                'is_closed': False,
#                'last_name': 'Мерзлякова'},
#               {'deactivated': 'banned',
#                'first_name': 'Андрей',
#                'id': 216,
#                'last_name': 'Мирных'},
#               {'can_access_closed': True,
#                'first_name': 'Alexander',
#                'id': 217,
#                'is_closed': False,
#                'last_name': 'Nasyrov'},
#               {'can_access_closed': True,
#                'first_name': 'Oksana',
#                'id': 218,
#                'is_closed': False,
#                'last_name': 'Zotova'},
#               {'deactivated': 'banned',
#                'first_name': 'Роман',
#                'id': 219,
#                'last_name': 'Акамёлков'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 220,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Наталья',
#                'id': 221,
#                'is_closed': False,
#                'last_name': 'Курчакова'},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 222,
#                'is_closed': False,
#                'last_name': 'Ступина'},
#               {'can_access_closed': True,
#                'first_name': 'Инга',
#                'id': 223,
#                'is_closed': False,
#                'last_name': 'Гладущик'},
#               {'can_access_closed': False,
#                'first_name': 'Ирина',
#                'id': 224,
#                'is_closed': True,
#                'last_name': 'Кирсанова'},
#               {'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 225,
#                'is_closed': False,
#                'last_name': 'Петропавловская'},
#               {'can_access_closed': False,
#                'first_name': 'Антон',
#                'id': 226,
#                'is_closed': True,
#                'last_name': 'Нестеров'},
#               {'can_access_closed': False,
#                'first_name': 'Ася',
#                'id': 227,
#                'is_closed': True,
#                'last_name': 'Лазо'},
#               {'can_access_closed': False,
#                'first_name': 'Дима',
#                'id': 228,
#                'is_closed': True,
#                'last_name': 'Мартиросов'},
#               {'can_access_closed': False,
#                'first_name': 'Гумер',
#                'id': 229,
#                'is_closed': True,
#                'last_name': 'Исаев'},
#               {'can_access_closed': True,
#                'first_name': 'Олеся',
#                'id': 230,
#                'is_closed': False,
#                'last_name': 'Дигина'},
#               {'can_access_closed': True,
#                'first_name': 'Юрий',
#                'id': 231,
#                'is_closed': False,
#                'last_name': 'Бычков'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 232,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Варя',
#                'id': 233,
#                'is_closed': False,
#                'last_name': 'Баранова'},
#               {'can_access_closed': False,
#                'first_name': 'Julia',
#                'id': 234,
#                'is_closed': True,
#                'last_name': 'Traub'},
#               {'can_access_closed': True,
#                'first_name': 'Фредерик',
#                'id': 235,
#                'is_closed': False,
#                'last_name': 'Булгаков'},
#               {'can_access_closed': True,
#                'first_name': 'Александра',
#                'id': 236,
#                'is_closed': False,
#                'last_name': 'Насекина'},
#               {'can_access_closed': False,
#                'first_name': 'Сергей',
#                'id': 237,
#                'is_closed': True,
#                'last_name': 'Журавлёв'},
#               {'can_access_closed': False,
#                'first_name': 'Татьяна',
#                'id': 238,
#                'is_closed': True,
#                'last_name': 'Тимофеева'},
#               {'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 239,
#                'is_closed': True,
#                'last_name': 'Степанова'},
#               {'deactivated': 'banned',
#                'first_name': 'Влад',
#                'id': 240,
#                'last_name': 'Коробейников'},
#               {'can_access_closed': True,
#                'first_name': 'Наташа',
#                'id': 241,
#                'is_closed': False,
#                'last_name': 'Власова'},
#               {'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 242,
#                'is_closed': False,
#                'last_name': 'Ёжиков'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 243,
#                'is_closed': False,
#                'last_name': 'Лапанович'},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 244,
#                'is_closed': False,
#                'last_name': 'Колдунова'},
#               {'can_access_closed': True,
#                'first_name': 'Zhenechka',
#                'id': 245,
#                'is_closed': False,
#                'last_name': 'Pimenofffffff'},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 246,
#                'is_closed': True,
#                'last_name': 'Попов'},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 247,
#                'is_closed': False,
#                'last_name': 'Гордеева'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 248,
#                'is_closed': False,
#                'last_name': 'Рейнгольд'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 249,
#                'is_closed': False,
#                'last_name': 'Карпова'},
#               {'can_access_closed': True,
#                'first_name': 'Юрий',
#                'id': 250,
#                'is_closed': False,
#                'last_name': 'Бабаин'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 251,
#                'is_closed': False,
#                'last_name': 'Чудотворов'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 252,
#                'is_closed': False,
#                'last_name': 'Микушев'},
#               {'can_access_closed': False,
#                'first_name': 'Karina',
#                'id': 253,
#                'is_closed': True,
#                'last_name': 'Mutlu'},
#               {'can_access_closed': True,
#                'first_name': 'Ася',
#                'id': 254,
#                'is_closed': False,
#                'last_name': 'Щёголь'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 255,
#                'is_closed': False,
#                'last_name': 'Уласень'},
#               {'can_access_closed': False,
#                'first_name': 'Ксения',
#                'id': 256,
#                'is_closed': True,
#                'last_name': 'Тинсли'},
#               {'deactivated': 'banned',
#                'first_name': 'Саша',
#                'id': 257,
#                'last_name': 'Дроздовский'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 258,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Катерина',
#                'id': 259,
#                'is_closed': True,
#                'last_name': 'Албу'},
#               {'can_access_closed': False,
#                'first_name': 'Анастасия',
#                'id': 260,
#                'is_closed': True,
#                'last_name': 'Графова'},
#               {'deactivated': 'banned',
#                'first_name': 'Nothing',
#                'id': 261,
#                'last_name': 'Personal'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 262,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 263,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Анна',
#                'id': 264,
#                'is_closed': False,
#                'last_name': 'Пугачёва'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 265,
#                'is_closed': False,
#                'last_name': 'Истомин'},
#               {'can_access_closed': True,
#                'first_name': 'Роман',
#                'id': 266,
#                'is_closed': False,
#                'last_name': 'Захаров'},
#               {'can_access_closed': False,
#                'first_name': 'Наталья',
#                'id': 267,
#                'is_closed': True,
#                'last_name': 'Бердникова'},
#               {'can_access_closed': False,
#                'first_name': 'Леонид',
#                'id': 268,
#                'is_closed': True,
#                'last_name': 'Ананьев'},
#               {'can_access_closed': True,
#                'first_name': 'Елена',
#                'id': 269,
#                'is_closed': False,
#                'last_name': 'Миненок'},
#               {'can_access_closed': False,
#                'first_name': 'Ирина',
#                'id': 270,
#                'is_closed': True,
#                'last_name': 'Рыбакова'},
#               {'can_access_closed': False,
#                'first_name': 'Александр',
#                'id': 271,
#                'is_closed': True,
#                'last_name': 'Селиванов'},
#               {'can_access_closed': False,
#                'first_name': 'Павел',
#                'id': 272,
#                'is_closed': True,
#                'last_name': 'Моржов'},
#               {'can_access_closed': False,
#                'first_name': 'Павел',
#                'id': 273,
#                'is_closed': True,
#                'last_name': 'Самойлов'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 274,
#                'is_closed': False,
#                'last_name': 'Тюрина'},
#               {'can_access_closed': False,
#                'first_name': 'Мария',
#                'id': 275,
#                'is_closed': True,
#                'last_name': 'Михайлова'},
#               {'can_access_closed': True,
#                'first_name': 'Катарина',
#                'id': 276,
#                'is_closed': False,
#                'last_name': 'Коровникова'},
#               {'can_access_closed': True,
#                'first_name': 'Александр',
#                'id': 277,
#                'is_closed': False,
#                'last_name': 'Кузнецов'},
#               {'can_access_closed': False,
#                'first_name': 'Мария',
#                'id': 278,
#                'is_closed': True,
#                'last_name': 'Грей'},
#               {'can_access_closed': False,
#                'first_name': 'Катя',
#                'id': 279,
#                'is_closed': True,
#                'last_name': 'Розенберг'},
#               {'can_access_closed': False,
#                'first_name': 'Вера',
#                'id': 280,
#                'is_closed': True,
#                'last_name': 'Семенова'},
#               {'can_access_closed': False,
#                'first_name': 'Мария',
#                'id': 281,
#                'is_closed': True,
#                'last_name': 'Иванова'},
# ...
#                'id': 406,
#                'is_closed': False,
#                'last_name': 'Шарко'},
#               {'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 407,
#                'is_closed': False,
#                'last_name': 'Железнов'},
#               {'can_access_closed': True,
#                'first_name': 'Ирина',
#                'id': 408,
#                'is_closed': False,
#                'last_name': 'Белова'},
#               {'can_access_closed': False,
#                'first_name': 'Виктория',
#                'id': 409,
#                'is_closed': True,
#                'last_name': 'Якунчикова'},
#               {'can_access_closed': False,
#                'first_name': 'Alexander',
#                'id': 410,
#                'is_closed': True,
#                'last_name': 'Obl'},
#               {'can_access_closed': False,
#                'first_name': 'Нина',
#                'id': 411,
#                'is_closed': True,
#                'last_name': 'Отмас'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 412,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 413,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 414,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 415,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 416,
#                'is_closed': False,
#                'last_name': 'Жаржавская'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 417,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'Юлия',
#                'id': 418,
#                'last_name': 'Эрние'},
#               {'can_access_closed': False,
#                'first_name': 'Ярослав',
#                'id': 419,
#                'is_closed': True,
#                'last_name': 'Воронцов'},
#               {'can_access_closed': True,
#                'first_name': 'Мария',
#                'id': 420,
#                'is_closed': False,
#                'last_name': 'Телегина'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 421,
#                'is_closed': False,
#                'last_name': 'Щёголева'},
#               {'can_access_closed': True,
#                'first_name': 'Дмитрий',
#                'id': 422,
#                'is_closed': False,
#                'last_name': 'Соколов'},
#               {'can_access_closed': False,
#                'first_name': 'Тимур',
#                'id': 423,
#                'is_closed': True,
#                'last_name': 'Кармов'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 424,
#                'last_name': ''},
#               {'deactivated': 'banned',
#                'first_name': 'Анна',
#                'id': 425,
#                'last_name': 'Войтенко'},
#               {'can_access_closed': False,
#                'first_name': 'Анна',
#                'id': 426,
#                'is_closed': True,
#                'last_name': 'Коновалова'},
#               {'can_access_closed': True,
#                'first_name': 'Алена',
#                'id': 427,
#                'is_closed': False,
#                'last_name': 'Матвейчук'},
#               {'can_access_closed': False,
#                'first_name': 'Александр',
#                'id': 428,
#                'is_closed': True,
#                'last_name': 'Кирпичников'},
#               {'can_access_closed': True,
#                'first_name': 'Михаил',
#                'id': 429,
#                'is_closed': False,
#                'last_name': 'Зубков'},
#               {'can_access_closed': True,
#                'first_name': 'Piotr',
#                'id': 430,
#                'is_closed': False,
#                'last_name': 'Gr'},
#               {'can_access_closed': False,
#                'first_name': 'Мария',
#                'id': 431,
#                'is_closed': True,
#                'last_name': 'Ажинова'},
#               {'can_access_closed': False,
#                'first_name': 'Ný',
#                'id': 432,
#                'is_closed': True,
#                'last_name': 'Lero'},
#               {'can_access_closed': True,
#                'first_name': 'Анастасия',
#                'id': 433,
#                'is_closed': False,
#                'last_name': 'Мальмрус'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 434,
#                'is_closed': False,
#                'last_name': 'Золотонос'},
#               {'can_access_closed': False,
#                'first_name': 'Кирилл',
#                'id': 435,
#                'is_closed': True,
#                'last_name': 'Субботин'},
#               {'deactivated': 'banned',
#                'first_name': 'Сергей',
#                'id': 436,
#                'last_name': 'Дюжев'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 437,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 438,
#                'is_closed': False,
#                'last_name': 'Шипилов'},
#               {'can_access_closed': True,
#                'first_name': 'Тимофей',
#                'id': 439,
#                'is_closed': False,
#                'last_name': 'Стороженко'},
#               {'can_access_closed': True,
#                'first_name': 'Anastasia',
#                'id': 440,
#                'is_closed': False,
#                'last_name': 'Balashova'},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 441,
#                'is_closed': False,
#                'last_name': 'Нигматуллина'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 442,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Алексей',
#                'id': 443,
#                'is_closed': True,
#                'last_name': 'Юрецкий'},
#               {'deactivated': 'banned',
#                'first_name': 'Алиса',
#                'id': 444,
#                'last_name': 'Иванова'},
#               {'can_access_closed': True,
#                'first_name': 'Филипп',
#                'id': 445,
#                'is_closed': False,
#                'last_name': 'Рамбов'},
#               {'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 446,
#                'is_closed': False,
#                'last_name': 'Богданов'},
#               {'can_access_closed': True,
#                'first_name': 'Marianna',
#                'id': 447,
#                'is_closed': False,
#                'last_name': 'Demenkova'},
#               {'deactivated': 'banned',
#                'first_name': 'Никита',
#                'id': 448,
#                'last_name': 'Аникеев'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 449,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Марина',
#                'id': 450,
#                'is_closed': False,
#                'last_name': 'Требина'},
#               {'deactivated': 'deleted',
#                'first_name': 'Ксения',
#                'id': 451,
#                'last_name': 'Грюнвальд'},
#               {'can_access_closed': True,
#                'first_name': 'Олег',
#                'id': 452,
#                'is_closed': False,
#                'last_name': 'Желтянников'},
#               {'can_access_closed': True,
#                'first_name': 'Ярославна',
#                'id': 453,
#                'is_closed': False,
#                'last_name': 'Гаген-Торн'},
#               {'can_access_closed': True,
#                'first_name': 'Андрей',
#                'id': 454,
#                'is_closed': False,
#                'last_name': 'Гук'},
#               {'can_access_closed': False,
#                'first_name': 'Евгений',
#                'id': 455,
#                'is_closed': True,
#                'last_name': 'Шехтер'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 456,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Владимир',
#                'id': 457,
#                'is_closed': False,
#                'last_name': 'Баранов'},
#               {'can_access_closed': True,
#                'first_name': 'Сергей',
#                'id': 458,
#                'is_closed': False,
#                'last_name': 'Нагапетян'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 459,
#                'last_name': ''},
#               {'deactivated': 'banned',
#                'first_name': 'Ilya',
#                'id': 460,
#                'last_name': 'Dneprovsky'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 461,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 462,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Людмила',
#                'id': 463,
#                'is_closed': False,
#                'last_name': 'Захарова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 464,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 465,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Anastasia',
#                'id': 466,
#                'is_closed': False,
#                'last_name': 'Mikhaylova'},
#               {'can_access_closed': True,
#                'first_name': 'Игорь',
#                'id': 467,
#                'is_closed': False,
#                'last_name': 'Перекопский'},
#               {'deactivated': 'banned',
#                'first_name': 'Паша',
#                'id': 468,
#                'last_name': 'Кипелов'},
#               {'can_access_closed': True,
#                'first_name': 'Екатерина',
#                'id': 469,
#                'is_closed': False,
#                'last_name': 'Пушкина'},
#               {'can_access_closed': True,
#                'first_name': 'Антон',
#                'id': 470,
#                'is_closed': False,
#                'last_name': 'Зайцев'},
#               {'can_access_closed': True,
#                'first_name': 'Дмитрий',
#                'id': 471,
#                'is_closed': False,
#                'last_name': 'Никончук'},
#               {'can_access_closed': True,
#                'first_name': 'Евгения',
#                'id': 472,
#                'is_closed': False,
#                'last_name': 'Захарова'},
#               {'can_access_closed': True,
#                'first_name': 'Алёна',
#                'id': 473,
#                'is_closed': False,
#                'last_name': 'Тайлер'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 474,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 475,
#                'last_name': ''},
#               {'can_access_closed': False,
#                'first_name': 'Лена',
#                'id': 476,
#                'is_closed': True,
#                'last_name': 'Самуйлова'},
#               {'deactivated': 'banned',
#                'first_name': 'Алексей',
#                'id': 477,
#                'last_name': 'Комаров'},
#               {'can_access_closed': False,
#                'first_name': 'Кирилл',
#                'id': 478,
#                'is_closed': True,
#                'last_name': 'Мошков'},
#               {'can_access_closed': True,
#                'first_name': 'Виктория',
#                'id': 479,
#                'is_closed': False,
#                'last_name': 'Стацевич'},
#               {'can_access_closed': False,
#                'first_name': 'Yarik',
#                'id': 480,
#                'is_closed': True,
#                'last_name': 'Markov'},
#               {'can_access_closed': True,
#                'first_name': 'Софья',
#                'id': 481,
#                'is_closed': False,
#                'last_name': 'Чебанова'},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 482,
#                'is_closed': False,
#                'last_name': 'Васильева'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 483,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Юлия',
#                'id': 484,
#                'is_closed': False,
#                'last_name': 'Нураева'},
#               {'deactivated': 'banned',
#                'first_name': 'Дарья',
#                'id': 485,
#                'last_name': 'Павлова'},
#               {'can_access_closed': False,
#                'first_name': 'Наталия',
#                'id': 486,
#                'is_closed': True,
#                'last_name': 'Юрасова'},
#               {'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 487,
#                'is_closed': True,
#                'last_name': 'Каткова'},
#               {'can_access_closed': True,
#                'first_name': 'Алексей',
#                'id': 488,
#                'is_closed': False,
#                'last_name': 'Леонидович'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 489,
#                'is_closed': True,
#                'last_name': 'Родионова'},
#               {'deactivated': 'deleted',
#                'first_name': 'Елена',
#                'id': 490,
#                'last_name': 'Ящике'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 491,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Кирилл',
#                'id': 492,
#                'is_closed': False,
#                'last_name': 'Ширяев'},
#               {'can_access_closed': True,
#                'first_name': 'Дарья',
#                'id': 493,
#                'is_closed': False,
#                'last_name': 'Монихарт'},
#               {'can_access_closed': False,
#                'first_name': 'Анна',
#                'id': 494,
#                'is_closed': True,
#                'last_name': 'Бабурова'},
#               {'can_access_closed': False,
#                'first_name': 'Михаил',
#                'id': 495,
#                'is_closed': True,
#                'last_name': 'Кадобнов'},
#               {'can_access_closed': True,
#                'first_name': 'Григорий',
#                'id': 496,
#                'is_closed': False,
#                'last_name': 'Малыгин'},
#               {'can_access_closed': False,
#                'first_name': 'Светлана',
#                'id': 497,
#                'is_closed': True,
#                'last_name': 'Лапина'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 498,
#                'last_name': ''},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 499,
#                'last_name': ''},
#               {'can_access_closed': True,
#                'first_name': 'Анонимный пользователь',
#                'id': 500,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.

# %%
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.48

# %% [markdown]
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 12999229, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9352, 9399, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 13008, 13063, 13080, 13173, 13224, 1323 ...

# %% [markdown]
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

# %%
#import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Сравним списки, полученные двумя способами:

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ
#
# → В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ
#
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 548,
#               'items': [{'attachments': [{'photo': {'access_key': 'be1c0ac7373447ccb7',
#                                                     'album_id': -7,
#                                                     'date': 1670430415,
#                                                     'id': 457337265,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-14.userapi.com/impg/o_Mx-yIdtY3deXWp0c0lDwoMHFE2rxGGlScTAA/qjkAEJMOuz4.jpg?size

#                                                                'type': 'z',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=1280x1200&quality=95&sign=3205a31b6a09d4522c2a60d1dc658895&c_uniq_tag=44TMWwFm4RjyG-HmozU40fcL3wlBjhIBJeQnlUrRFRs&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2157,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=2300x2157&quality=95&sign=5574b9f741c897b76107dd296eca424c&c_uniq_tag=Y4ifgyylVZIHfbFK7VAEeq652oMg80NAKOX72ACW5sc&type=album',
#                                                                'width': 2300},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=130x122&quality=95&sign=4ffa625823e5ce2ddc4101d237767c64&c_uniq_tag=1J7fzjB4G-TNJ1oocpVi7CUA5-kWExTvfh-7Kohetik&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=200x188&quality=95&sign=612a59d7122196f93b97ee41069c1159&c_uniq_tag=K0lTzpE6pYiLZHG8xFfjJ4SoAM8iB_DmCEb5NvEtHHU&type=album',
#                                                                'width': 200},
#                                                               {'height': 300,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=320x300&quality=95&sign=83d40da656395300ee88aac860ff5ad1&c_uniq_tag=Ihc5GjfcrnljvmvGbb6gFzV4EMz9-nZvpKpCJ5A8rlg&type=album',
#                                                                'width': 320},
#                                                               {'height': 478,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-99.userapi.com/impg/R9FNp_TnjjJsN6-hpQnB-u4LHph-i--smfRb0A/94ND4UXAPzY.jpg?size=510x478&quality=95&sign=1410cc789beb1eaf0a71ce5b28693012&c_uniq_tag=oAS3xD--3msyq7NBhRwp3BbBQd4LmiI14DV-YR4EHG0&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2732,
#                                       'groups_can_post': True},
#                          'date': 1669722855,
#                          'from_id': -22822305,
#                          'hash': 'Ztm2_7yseZBNnArsoA',
#                          'id': 1356902,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1639,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 595, 'user_reposted': 0},
#                          'text': 'Теперь в профиле можно закрепить любой '
#                                  'раздел с контентом по вашему выбору. Это '
#                                  'поможет кастомизировать аккаунт и сделать '
#                                  'акцент на тех материалах, которые лучше '
#                                  'всего презентуют вас. \n'
#                                  '\n'
#                                  'Чтобы выбрать раздел, нажмите на шестерёнку '
#                                  'в правом верхнем углу. Если закрепляете с '
#                                  'телефона, зажмите раздел и отредактируйте '
#                                  'его. У закреплённого блока появится значок '
#                                  'пина.\n'
#                                  '\n'
#                                  'Не забудьте обновить обложку. Так ваш '
#                                  'профиль станет настоящей визитной карточкой, '
#                                  'где каждый элемент органично дополняет '
#                                  'картину и представляет ваш контент наилучшим '
#                                  'образом.',
#                          'views': {'count': 632383}},
#                         {'attachments': [{'link': {'caption': 'vc.ru',
#                                                    'description': 'С '
#                                                                   'миллионами '
#                                                                   'часов '
#                                                                   'голосовых и '
#                                                                   'звуком «ъ».',
#                                                    'photo': {'album_id': -27,
#                                                              'date': 1669623589,
#                                                              'id': 457410254,
#                                                              'owner_id': 2000051785,
#                                                              'sizes': [{'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=1074x480&quality=96&sign=0ecb9c8a03e8f8006817ac710879ff70&c_uniq_tag=IeuzFbpDbpMjAn5unGT-pCxAYWkGp2lzc4gIlZZgN-M&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=537x240&quality=96&sign=39f7ecb35dd19adf26e1ae836e9edea6&c_uniq_tag=v-ErLzx__AfX_BNiNdKyKJQznqQgDlBjapaYHzPksiU&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 80,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=f093f9d06d884d1a7ecf8dfb92983d96&c_uniq_tag=YuaM1cMPmw_qNEBSRvfVGPEXHpRPsMvmNxrHCrp4z4o&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 140,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=34ac547270df0bd090a94790ce933339&c_uniq_tag=39IYcaR5tvGzmI6HPSCBzpt07K_QFhI7wkcyquTtQBU&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 35,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=d7a961d04b27aef6336b36b979b4740f&c_uniq_tag=XUx_NNXFjLzPn2Xkq7uB5Shg7NY_Hy7VgNq9eVM0pNQ&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 80,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun1-29.userapi.com/impg/3HyV30zNEWicleQmTWMby7DJH7GBDaznf3z1xg/FZCdYyc2_2g.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=41fc153074c149cb2883b5fbba90bcbf&c_uniq_tag=RnbFnEQR22hz7NviTACQRdBFs_m1b3zpiW9UnA0SBc4&type=share',
#                                                                         'width': 150}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Извини, что '
#                                                             'голосом: как '
#                                                             'развивалось '
#                                                             'распознавание '
#                                                             'речи ВКонтакте',
#                                                    'url': 'http://vc.ru/vk/547876-izvini-chto-golosom-kak-razvivalos-raspoznavanie-rechi-vkontakte-2VtzqvwdZ9K'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 362,
#                                       'groups_can_post': True},
#                          'date': 1669649531,
#                          'from_id': -22822305,
#                          'hash': 'ufhWJusAGXCm7SxJsg',
#                          'id': 1356539,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1136,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 259, 'user_reposted': 0},
#                          'text': 'Отправляете голосовые, когда нет времени '
#                                  'писать длинные сообщения? Или не любите '
#                                  'слушать и предпочитаете переписки? Неважно, '
#                                  'на какой вы стороне, — общаться так, как '
#                                  'нравится, помогает расшифровка голосовых '
#                                  'сообщений. \n'
#                                  '\n'
#                                  'В основе распознавания голосовых ВКонтакте '
#                                  'лежит технология ASR, которая переводит '
#                                  'устную речь в текст. Инструмент породил '
#                                  'шутки, мемы и популярные челленджи. Но, '
#                                  'главное, мы получили положительные отзывы от '
#                                  'пользователей. Поэтому теперь используем ASR '
#                                  'в других продуктах и даже открыли доступ к '
#                                  'технологии для независимых разработчиков. \n'
#                                  '\n'
#                                  'Как эволюционировала наша собственная '
#                                  'технология ASR и при чём тут звук «ъ» — '
#                                  'читайте в статье на vc.ru.',
#                          'views': {'count': 701921}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 

#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 226, 'user_reposted': 0},
#                          'text': 'Смотрите любимые ролики в высоком разрешении '
#                                  '— даже если они были сняты на камеру '
#                                  'смартфона 10 лет назад. За качество картинки '
#                                  'в VK Видео теперь отвечает собственная '
#                                  'технология NeuroHD. Видеозаписи в разрешении '
#                                  '480р будут доступны в 720р, а HD-ролики '
#                                  'можно улучшить до 2К. \n'
#                                  '\n'
#                                  'NeuroHD не только увеличивает разрешение. '
#                                  'Технология также позволяет убирать шумы, '
#                                  'восстанавливать детали и устранять дефекты '
#                                  'изображения в режиме реального времени. '
#                                  'Секрет в архитектуре, которую мы создали: '
#                                  'она не требует многоэтапной обработки видео '
#                                  'и позволяет повышать качество за одну '
#                                  'итерацию. Важную роль в обучении нейросети '
#                                  'сыграла многомиллионная библиотека VK Видео. '
#                                  'С её помощью мы смогли обучить нейросеть на '
#                                  'видео разных форматов: профессиональных и '
#                                  'любительских, горизонтальных и вертикальных, '
#                                  'динамических и статичных, длиной в часы или '
#                                  'несколько секунд.\n'
#                                  '\n'
#                                  'Проще говоря, видеозаписи улучшаются на '
#                                  'ваших глазах — ждать не придётся. Попробуйте '
#                                  'сами: оценить эффект NeuroHD можно уже '
#                                  'сейчас в некоторых группах и публичных '
#                                  'страницах. Например, в '
#                                  '[https://vk.com/video/@ifeed|iFeed], '
#                                  '[https://vk.com/video/@englishpolls|«Учим '
#                                  'английский язык»] или '
#                                  '[https://vk.com/video/@kn_rec|«Смотри, что я '
#                                  'узнал»].\n'
#                                  ' \n'
#                                  'Отправить запрос, чтобы улучшить качество '
#                                  'видео может администратор любого сообщества. '
#                                  'Для этого нужно заполнить '
#                                  '[https://vk.com/support?act=new&from=upd_video|форму].',
#                          'views': {'count': 1183099}},
#                         {'attachments': [{'link': {'caption': 'vk.com',
#                                                    'description': 'ВКонтакте '
#                                                                   'подвела '
#                                                                   'итоги '
#                                                                   '2021-го '
#                                                                   'года. '
#                                                                   'Музыка. '
#                                                                   'Персоны и '
#                                                                   'темы. '
#                                                                   'Клипы. '
#                                                                   'Сервисы. '
#                                                                   'E-commerce. '
#                                                                   'Авторы и '
#                                                                   'лента. '
#                                                                   'Технологии. '
#                                                                   'Мемы.',
#                                                    'photo': {'album_id': -27,
#                                                              'date': 1639167016,
#                                                              'id': 457369521,
#                                                              'owner_id': 2000003133,
#                                                              'sizes': [{'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=1074x480&quality=96&sign=12ce3f412b98acc603ea8d84df2d5990&c_uniq_tag=2B9srmQppUGthIZEFlOXOmh9-ceHKOGkoIaPd0ZyEzc&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=537x240&quality=96&sign=a309f8ea5840ec82792e75e7c5f86370&c_uniq_tag=sXt5x2GpmsstRihqgxzGsHkpSy9fHQ_6g8behyJGhRE&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 80,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=ebd391e19d1c078bd154262a29c3df46&c_uniq_tag=qTbsD_aHfaKXmgHqftIyuTZ7xvE4DevVbckBSngdV2g&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 140,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=a5494bfc0d90c31457fa964b8be10070&c_uniq_tag=hUhavqveVbeRKB8SHwXuyoKKWekq13sr-lJcYABhycE&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 35,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=2cfa0616bae23ffd8fc7066d0ee20a73&c_uniq_tag=eZTX37P4bCLGReJZ3j9nSIOVzdDQQiTWWM0f9qPEdVE&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 80,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun9-82.userapi.com/impg/0JJbWnpBTU-mcpFCGGL5hYdrGzF15BMkwYM-3g/CB1UFU84GLk.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=7022a5cf889d3bb518f5bd16b56f4f74&c_uniq_tag=e8FUGKxfKRJu4EaOINfiiuPGJ22va4FQSTjlq1bP0G8&type=share',
#                                                                         'width': 150}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Итоги года '
#                                                             'ВКонтакте 2021',
#                                                    'url': 'https://vk.com/2021'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1172,
#                                       'groups_can_post': True},
#                          'date': 1639138500,
#                          'edited': 1639167016,
#                          'from_id': -22822305,
#                          'hash': 'Iwni-Zi80FWWvuMJCA',
#                          'id': 1251019,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2777,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2212, 'user_reposted': 0},
#                          'text': 'Этот год оказался богатым на события — всем '
#                                  'нам было что обсудить. Начинаем подводить '
#                                  'итоги 2021-го. Сегодня делимся списком тем и '
#                                  'персон, о которых чаще всего говорили '
#                                  'пользователи ВКонтакте. \n'
#                                  '\n'
#                                  'Самой волнующей темой в 2021 году остаётся '
#                                  'пандемия COVID-19. Пользователи писали не '
#                                  'только про коронавирус, но и про вакцинацию, '
#                                  'удалённую работу, осенний локдаун и систему '
#                                  'QR-кодов. Суммарно все эти вопросы '
#                                  'обсуждались 68,5 млн раз. Также большой '
#                                  'интерес вызывали общественно-политические '
#                                  'новости. Уже несколько лет подряд рейтинг '
#                                  'самых упоминаемых персон возглавляет '
#                                  'Владимир Путин. В топе и лидеры других '
#                                  'стран: Владимир Зеленский, Александр '
#                                  'Лукашенко, 45-й президент США Дональд '
#                                  'Трамп. \n'
#                                  '\n'
#                                  'Пользователей ВКонтакте увлекали музыканты: '
#                                  'они заняли почти половину позиций в топ-15 '
#                                  'самых упоминаемых персон. К примеру, на '
#                                  'третьем месте — k-pop-группа BTS. Кроме '
#                                  'того, в рейтинг попали популярные культурные '
#                                  'и спортивные события: пользователи ВКонтакте '
#                                  'следили за «Евровидением», премией «Оскар», '
#                                  'Евро-2020 и Олимпиадой в Токио. \n'
#                                  '\n'
#                                  'Мы продолжим делиться итогами года в течение '
#                                  'всего декабря. Заглядывайте в специальный '
#                                  'раздел: vk.com/2021.',
#                          'views': {'count': 703586}}]}}

# %% [markdown]
# Анализируя ответ, понимаем, что по ключу count можно найти общее количество сообщений в новостной ленте, а по ключу items — сами сообщения.
#
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'VK Мессенджер стал самым попул': [428, 1315, 459, 1669042337],
#  'За год вы посмотрели 251 милли': [335, 705, 181, 1670338226],
#  'Как думаете, сколько людей пос': [346, 1514, 535, 1668703817],
#  'Нейросети помогают не только с': [820, 1693, 1051, 1669277367],
#  'Отправляете голосовые, когда н': [362, 1136, 259, 1669649531],
#  'Помогать — просто! В сервисе [': [272, 543, 74, 1670234514],
#  'Приближаем Новый год и уже дел': [877, 1491, 594, 1670068803],
#  'Собрали в блоге [vk.com/blog/d': [86, 361, 67, 1670428500],
#  'Теперь в профиле можно закрепи': [2732, 1639, 595, 1669722855],
#  'Хотим поделиться приятными нов': [216, 980, 360, 1669117035]}

# %% [markdown]
# КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК
#
# Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют задачей (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль schedule (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль schedule не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %% [markdown]
# Для того чтобы у нас появилась возможность использовать модуль в коде, импортируем его:

# %%
import schedule # Импортируем модуль schedule

# %% [markdown]
# Теперь можно приступать к работе!
#
# ПОСТАНОВКА ЗАДАЧИ
#
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %% [markdown]
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле schedule используется метод every(), который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.
#
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:

# %%
schedule.every(15).minutes.do(task)
# Out:
# Every 15 minutes do task() (last run: [never], next run: 2022-12-08 15:11:53)

# %% [markdown]
# Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:

# %%
schedule.every(1).hour.do(task)
# Out:
# Every 1 hour do task() (last run: [never], next run: 2022-12-08 15:57:53)

# %% [markdown]
# ВЫПОЛНЕНИЕ ФУНКЦИИ
#
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:

# %%
import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)

# %% [markdown]
# Всё готово — теперь можно сохранить файл и выполнить код.
#
# Вот какой код в итоге получился:

# %%
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(15).minutes.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)

# %% [markdown]
# Этот код будет каждую секунду проверять, не надо ли выполнить какую-то задачу, и раз в 15 минут будет выводить на экран фразу: "Hello! I am a task!" Вывод сообщения будет повторяться до тех пор, пока вы не остановите выполнение скрипта.
